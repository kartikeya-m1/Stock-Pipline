# %%
import pandas as pd
import os

processed_dir = "../data/processed"

# Load TSLA first (you can change ticker later)
tsla_path = os.path.join(processed_dir, "TSLA_clean.parquet")

df = pd.read_parquet(tsla_path)

df.head()
# Out:
#                   Date        Open        High         Low       Close  \
# 0  2024-11-25 05:00:00  360.140015  361.929993  338.200012  338.589996
# 1  2024-11-26 05:00:00  341.000000  346.959991  335.660004  338.230011
# 2  2024-11-27 05:00:00  341.799988  342.549988  326.589996  332.890015
# 3  2024-11-29 05:00:00  336.079987  345.450012  334.649994  345.160004
# 4  2024-12-02 05:00:00  352.380005  360.000000  351.149994  357.089996
#
#      Volume  Dividends  Stock Splits
# 0  95890900        0.0           0.0
# 1  62295900        0.0           0.0
# 2  57896400        0.0           0.0
# 3  37167600        0.0           0.0
# 4  77986500        0.0           0.0

# %%
# !pip install pyarrow
# Out:
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: pyarrow in c:\users\vivoboook\anaconda3\envs\shreeyanm2\lib\site-packages (16.1.0)
# Requirement already satisfied: numpy>=1.16.6 in c:\users\vivoboook\anaconda3\envs\shreeyanm2\lib\site-packages (from pyarrow) (1.26.4)

# %%
# !pip uninstall pyarrow -y
# !pip install fastparquet
# Out:
# Found existing installation: pyarrow 16.1.0
# Uninstalling pyarrow-16.1.0:
#   Successfully uninstalled pyarrow-16.1.0
# Collecting fastparquet
#   Downloading fastparquet-2024.11.0-cp312-cp312-win_amd64.whl.metadata (4.3 kB)
# Requirement already satisfied: pandas>=1.5.0 in c:\users\vivoboook\anaconda3\envs\shreeyanm2\lib\site-packages (from fastparquet) (2.3.2)
# Requirement already satisfied: numpy in c:\users\vivoboook\anaconda3\envs\shreeyanm2\lib\site-packages (from fastparquet) (1.26.4)
# Collecting cramjam>=2.3 (from fastparquet)
#   Downloading cramjam-2.11.0-cp312-cp312-win_amd64.whl.metadata (681 bytes)
# Requirement already satisfied: fsspec in c:\users\vivoboook\anaconda3\envs\shreeyanm2\lib\site-packages (from fastparquet) (2024.3.1)
# Requirement already satisfied: packaging in c:\users\vivoboook\anaconda3\envs\shreeyanm2\lib\site-packages (from fastparquet) (23.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\vivoboook\anaconda3\envs\shreeyanm2\lib\site-packages (from pandas>=1.5.0->fastparquet) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\vivoboook\anaconda3\envs\shreeyanm2\lib\site-packages (from pandas>=1.5.0->fastparquet) (2023.4)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\vivoboook\anaconda3\envs\shreeyanm2\lib\site-packages (from pandas>=1.5.0->fastparquet) (2023.4)
# Requirement already satisfied: six>=1.5 in c:\users\vivoboook\anaconda3\envs\shreeyanm2\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.5.0->fastparquet) (1.16.0)
# Downloading fastparquet-2024.11.0-cp312-cp312-win_amd64.whl (673 kB)
#    ---------------------------------------- 0.0/673.3 kB ? eta -:--:--
#    ---------------------------------------- 673.3/673.3 kB 8.7 MB/s eta 0:00:00
# Downloading cramjam-2.11.0-cp312-cp312-win_amd64.whl (1.7 MB)
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ------------ --------------------------- 0.5/1.7 MB 1.7 MB/s eta 0:00:01
#    ---------------------------------------- 1.7/1.7 MB 3.9 MB/s eta 0:00:00
# Installing collected packages: cramjam, fastparquet
#
#    ---------------------------------------- 2/2 [fastparquet]
#
# Successfully installed cramjam-2.11.0 fastparquet-2024.11.0
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
